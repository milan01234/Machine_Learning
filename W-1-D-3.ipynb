# %%
pip install NumPy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
array=np.array([[1,2,3,4,],[5,6,7,8]])
print(array)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(array.ndim)
# Out:
# 2

# %%
from numpy import random
x=random.randint(10)
print(x)
# Out:
# 0.7255574232925418

# %%
x=random.rand()
print(x)
# Out:
# 0.9432345690441941

# %%
x=random.randint(100,size=(5))
print(x)
# Out:
# [75 87 36 65 29]

# %%
x=random.randint(100,size=(3,5))
print(x)
# Out:
# [[40  7 99 47 40]
#  [ 7  7 79 84 70]
#  [45 37 66  0 18]]

# %%
import numpy as np
in_arr=np.array([8])
print("input array is",in_arr)
out_scalar=np.asscalar(in_arr)
print("output scalar from input array",out_scalar)
# Out:
# input array is [8]
# output scalar from input array 8
# C:\Users\milan\AppData\Local\Temp\ipykernel_37060\2035694596.py:4: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   out_scalar=np.asscalar(in_arr)

# %%
#creating 1-d list
list1=[1,2,3]
#creating 2-d list
list2=[[10],[20],[30]]
vector1=np.array(list1)
vector2=np.array(list2)

print("horizontal vector")
print(vector1)
print("------------------------")
print("vertical vector")
print(vector2)
# Out:
# horizontal vector
# [1 2 3]
# ------------------------
# vertical vector
# [[10]
#  [20]
#  [30]]

# %%
a=np.matrix('0 2 3;3 4 5')
print("via string input:\n",a,"\n\n")
#array-like input
b=np.matrix([[5,6,7,8],[1,2,3,4],[4]])
print("via array like input:\n",b)
# Out:
# via string input:
#  [[0 2 3]
#  [3 4 5]]
#
#
# via array like input:
#  [[list([5, 6, 7, 8]) list([1, 2, 3, 4]) list([4])]]

# %%
a=5
b=[[6,7],[8,9]]
print(np.dot(a,b))
# Out:
# [[30 35]
#  [40 45]]

# %%
a=[[6,7],[8,9]]
b=[[1,3],[5,7]]
print(np.dot(a,b))
print("-------------")
print(np.dot(b,a))
# Out:
# [[41 67]
#  [53 87]]
# -------------
# [[30 34]
#  [86 98]]

# %%
arr=np.array([[1,23,78],[98,60,75],[79,25,40]])
print(arr)
#min function
print(np.amin(arr))
#max function
print(np.amax(arr))
# Out:
# [[ 1 23 78]
#  [98 60 75]
#  [79 25 40]]
# 1
# 98

# %%
a=np.array([5,6,7])
print(a)
print("mean of array a",np.mean(a))
print("median of array a=",np.median(a))
print("standard eviation of array a=",np.std(a))
print("variance of array a=",np.var(a))
# Out:
# [5 6 7]
# mean of array a 6.0
# median of array a= 6.0
# standard eviation of array a= 0.816496580927726
# variance of array a= 0.6666666666666666

# %%
import numpy as np
data=[32,36,46,47,56,69,75,79,79,88,89,91,92,93,96,97,101,105,112,116]
q1=np.median(data[0:10])
q3=np.median(data[10:])
print(q1)
print("-------------")
print(q3)
iqr=q3-q1
print("-------------")
print(iqr)
# Out:
# 62.5
# -------------
# 96.5
# -------------
# 34.0

# %%
a=np.array([1,2,3])
b=np.array([2,3,4])
print(a*b)
# Out:
# [ 2  6 12]

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
#impot matplotlib
import matplotlib.pyplot as plt
#x-axis cordination
x=[2,2,6]
#y-axis cordination
y=[3,4,5]
z=[7,8,9]
#call draw function to draw plot
plt.plot(x,y,z)
plt.plot(y,x,z)
#call show function to show plot on output
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([3,8,1,10])
plt.plot(ypoint,marker='o',color='y',linestyle='dashdot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('My first graph')
plt.show()

# %%
plt.scatter(x,y,marker='*')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,15,0.1)
y=np.sin(x)
#figure in matplotlib using figure()
plt.figure(figsize=(4,4))
plt.plot(x,y)
plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(3,3,1)
plt.plot(x,y)

 #plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,6)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,7)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,(8,9))
plt.plot(x,y)

# %%
x=[1,2,3,4,5,6,7,8]
y=[8,7,6,5,4,3,2,1]
plt.bar(x,y)
ply.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5944\3954856637.py in <module>
#       2 y=[8,7,6,5,4,3,2,1]
#       3 plt.bar(x,y)
# ----> 4 ply.show()
#
# NameError: name 'ply' is not defined

# %%
x=[5,2,9,4,7,3,8,10,1]
y=[10,5,8,4,2,1,6,3,9]
plt.scatter(x,y)
plt.show()

# %%
x=[5,10,15,20,25,30,35,40,45,50]
y=[1,4,3,2,7,6,9,8,10,5]
plt.plot(x,y,'g')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis="x",labelsize=18,labelrotation=60,labelcolor="blue")
plt.tick_params(axis="y",labelsize=12,labelrotation=20,labelcolor="black")

plt.show()

# %%
y1=[2,3,4.5]
y2=[1,1.5,5]
plt.plot(y1)
plt.plot(y2)
plt.legend(["blue","green"],loc="lower right")
plt.show()

# %%
data=np.random.normal(170,10,250)
plt.hist(data);
plt.show()
plt.hist(data,bins=30);
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,20,100)
fig, ax=plt.subplots()
ax.plot(x,np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28,1), xytext=(10,4) , arrowprops=dict(facecolor= 'black',shrink=0.05))
ax.annotate('local minimum', xy=(5*np.pi,-1) , xytext=(2,-6) , arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=90"));

# %%
w=4
h=3
d=70
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x=[0,3,5]
y=[1,4,3.5]
label_x=1
label_y=4
arrow_x=3
arrow_y=4
arrow_properties=dict(facecolor="red",width=0.2,headwidth=4,shrink=0.1)
plt.annotate("maximum", xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_properties)
plt.plot(x,y)

# %%
from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')
z=np.linspace(0,1,100)
x=z*np.sin(10*z)
y=z*np.cos(30*z)
ax.plot3D(x,y,z,'red')
ax.set_title('3d line plot')
plt.show()

# %%
cars=['audi','bmw','ford','tesla','jaguar','mercedes']
data=[23,17,35,29,12,41]
fig=plt.figure(figsize=(8,5))
plt.pie(data,labels=cars)
plt.show()
